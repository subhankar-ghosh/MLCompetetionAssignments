# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
  np.random.seed(0)
  return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
  np.random.seed(1)
  X = 10 * np.random.randn(num_inputs, input_size)
  y = np.array([0, 1, 2, 2, 1])
  return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print( 'Your scores:')
print( scores)
print()
print( 'correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print( correct_scores)
print()

# The difference should be very small. We get < 1e-7
print( 'Difference between your scores and correct scores:')
print( np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027209255e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print( 'Difference between your loss and correct loss:')
print( np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.79412040779e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.1)

# these should all be less than 1e-8 or so
for param_name in grads:
  f = lambda W: net.loss(X, y, reg=0.1)[0]
  param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
  #print(param_name)
  #print(param_grad_num)
  #print(grads[param_name])
  print( '%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# b2 max relative error: 3.865070e-11
# W2 max relative error: 3.333333e-01
# b1 max relative error: 1.000000e+00
# W1 max relative error: 1.000000e+00

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=1e-5,
            num_iters=100, verbose=False)

print( 'Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# 5
# 200
# Final training loss:  0.860196999317

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print( 'Train labels shape: ', y_train.shape)
print( 'Validation data shape: ', X_val.shape)
print( 'Validation labels shape: ', y_val.shape)
print( 'Test data shape: ', X_test.shape)
print( 'Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print ('Validation accuracy: ', val_acc)
# Out:
# 49000
# 200
# iteration 0 / 1000: loss 2.302974
# iteration 100 / 1000: loss 2.302725
# iteration 200 / 1000: loss 2.301225
# iteration 300 / 1000: loss 2.285459
# iteration 400 / 1000: loss 2.245180
# iteration 500 / 1000: loss 2.253025
# iteration 600 / 1000: loss 2.166254
# iteration 700 / 1000: loss 2.132988
# iteration 800 / 1000: loss 2.071393
# iteration 900 / 1000: loss 2.125258
# Validation accuracy:  0.25

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train', color='red')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
  W1 = net.params['W1']
  W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
  plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
  plt.gca().axis('off')
  plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 
results = {}
best_val = -1
learning_rates = [1e-4, 2e-4, 4e-4, 5e-4] #np.logspace(-10, 10, 10)
regularization_strengths = [1e-2, 5e-1, 1e0, 5e0, 1e1, 1e2] #np.logspace(-3, 6, 10)

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
for lr in learning_rates:
    for rs in regularization_strengths:
        net = TwoLayerNet(input_size, hidden_size, num_classes)
        stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1500, batch_size=200,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=rs, verbose=True)

        y_train_pred = net.predict(X_train)
        tracc = (np.mean(y_train == y_train_pred))
        print( 'training accuracy: %f' % tracc)
        y_val_pred = net.predict(X_val)
        valacc = np.mean(y_val == y_val_pred)
        print( 'validation accuracy: %f' % valacc )
        results[(lr,rs)]=(tracc, valacc)
        if(best_val < valacc):
            best_val = valacc
            best_net = net

#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print ('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print( 'best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# 49000
# 200
# iteration 0 / 500: loss 2.302556
# iteration 100 / 500: loss 2.302579
# iteration 200 / 500: loss 2.302563
# iteration 300 / 500: loss 2.302583
# iteration 400 / 500: loss 2.302579
# training accuracy: 0.112163
# validation accuracy: 0.115000
# 49000
# 200
# iteration 0 / 500: loss 2.302593
# iteration 100 / 500: loss 2.302612
# iteration 200 / 500: loss 2.302608
# iteration 300 / 500: loss 2.302602
# iteration 400 / 500: loss 2.302624
# training accuracy: 0.111959
# validation accuracy: 0.124000
# 49000
# 200
# iteration 0 / 500: loss 2.302663
# iteration 100 / 500: loss 2.302656
# iteration 200 / 500: loss 2.302627
# iteration 300 / 500: loss 2.302648
# iteration 400 / 500: loss 2.302617
# training accuracy: 0.117837
# validation accuracy: 0.140000
# 49000
# 200
# iteration 0 / 500: loss 2.303369
# iteration 100 / 500: loss 2.303349
# iteration 200 / 500: loss 2.303360
# iteration 300 / 500: loss 2.303353
# iteration 400 / 500: loss 2.303375
# training accuracy: 0.076306
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.310328
# iteration 100 / 500: loss 2.310326
# iteration 200 / 500: loss 2.310321
# iteration 300 / 500: loss 2.310337
# iteration 400 / 500: loss 2.310328
# training accuracy: 0.089714
# validation accuracy: 0.082000
# 49000
# 200
# iteration 0 / 500: loss 2.379211
# iteration 100 / 500: loss 2.379198
# iteration 200 / 500: loss 2.379206
# iteration 300 / 500: loss 2.379209
# iteration 400 / 500: loss 2.379222
# training accuracy: 0.095857
# validation accuracy: 0.083000
# 49000
# 200
# iteration 0 / 500: loss 3.068092
# iteration 100 / 500: loss 3.068077
# iteration 200 / 500: loss 3.068080
# iteration 300 / 500: loss 3.068088
# iteration 400 / 500: loss 3.068061
# training accuracy: 0.114653
# validation accuracy: 0.099000
# 49000
# 200
# iteration 0 / 500: loss 10.029882
# iteration 100 / 500: loss 10.029137
# iteration 200 / 500: loss 10.028416
# iteration 300 / 500: loss 10.027698
# iteration 400 / 500: loss 10.026990
# training accuracy: 0.096980
# validation accuracy: 0.105000
# 49000
# 200
# iteration 0 / 500: loss 79.589976
# iteration 100 / 500: loss 79.516563
# iteration 200 / 500: loss 79.443240
# iteration 300 / 500: loss 79.371965
# iteration 400 / 500: loss 79.302467
# training accuracy: 0.087184
# validation accuracy: 0.079000
# 49000
# 200
# iteration 0 / 500: loss 775.003162
# iteration 100 / 500: loss 767.693260
# iteration 200 / 500: loss 760.456307
# iteration 300 / 500: loss 753.480455
# iteration 400 / 500: loss 746.731419
# training accuracy: 0.103673
# validation accuracy: 0.113000
# 49000
# 200
# iteration 0 / 500: loss 2.302597
# iteration 100 / 500: loss 2.302595
# iteration 200 / 500: loss 2.302616
# iteration 300 / 500: loss 2.302569
# iteration 400 / 500: loss 2.302577
# training accuracy: 0.103367
# validation accuracy: 0.082000
# 49000
# 200
# iteration 0 / 500: loss 2.302603
# iteration 100 / 500: loss 2.302595
# iteration 200 / 500: loss 2.302598
# iteration 300 / 500: loss 2.302580
# iteration 400 / 500: loss 2.302612
# training accuracy: 0.099306
# validation accuracy: 0.115000
# 49000
# 200
# iteration 0 / 500: loss 2.302627
# iteration 100 / 500: loss 2.302658
# iteration 200 / 500: loss 2.302672
# iteration 300 / 500: loss 2.302676
# iteration 400 / 500: loss 2.302691
# training accuracy: 0.109490
# validation accuracy: 0.086000
# 49000
# 200
# iteration 0 / 500: loss 2.303346
# iteration 100 / 500: loss 2.303363
# iteration 200 / 500: loss 2.303366
# iteration 300 / 500: loss 2.303371
# iteration 400 / 500: loss 2.303364
# training accuracy: 0.092612
# validation accuracy: 0.088000
# 49000
# 200
# iteration 0 / 500: loss 2.310266
# iteration 100 / 500: loss 2.310296
# iteration 200 / 500: loss 2.310286
# iteration 300 / 500: loss 2.310278
# iteration 400 / 500: loss 2.310288
# training accuracy: 0.111816
# validation accuracy: 0.106000
# 49000
# 200
# iteration 0 / 500: loss 2.379574
# iteration 100 / 500: loss 2.379570
# iteration 200 / 500: loss 2.379568
# iteration 300 / 500: loss 2.379555
# iteration 400 / 500: loss 2.379531
# training accuracy: 0.086653
# validation accuracy: 0.093000
# 49000
# 200
# iteration 0 / 500: loss 3.068053
# iteration 100 / 500: loss 3.066831
# iteration 200 / 500: loss 3.065628
# iteration 300 / 500: loss 3.064444
# iteration 400 / 500: loss 3.063312
# training accuracy: 0.087857
# validation accuracy: 0.081000
# 49000
# 200
# iteration 0 / 500: loss 10.010681
# iteration 100 / 500: loss 9.889414
# iteration 200 / 500: loss 9.770142
# iteration 300 / 500: loss 9.655878
# iteration 400 / 500: loss 9.545984
# training accuracy: 0.104592
# validation accuracy: 0.105000
# 49000
# 200
# iteration 0 / 500: loss 79.395781
# iteration 100 / 500: loss 68.088063
# iteration 200 / 500: loss 58.443596
# iteration 300 / 500: loss 50.418661
# iteration 400 / 500: loss 43.691520
# training accuracy: 0.078837
# validation accuracy: 0.084000
# 49000
# 200
# iteration 0 / 500: loss 774.749314
# iteration 100 / 500: loss 159.533441
# iteration 200 / 500: loss 34.333712
# iteration 300 / 500: loss 9.115507
# iteration 400 / 500: loss 3.805890
# training accuracy: 0.093694
# validation accuracy: 0.106000
# 49000
# 200
# iteration 0 / 500: loss 2.302586
# iteration 100 / 500: loss 2.302565
# iteration 200 / 500: loss 2.302591
# iteration 300 / 500: loss 2.302564
# iteration 400 / 500: loss 2.302572
# training accuracy: 0.135816
# validation accuracy: 0.135000
# 49000
# 200
# iteration 0 / 500: loss 2.302608
# iteration 100 / 500: loss 2.302602
# iteration 200 / 500: loss 2.302581
# iteration 300 / 500: loss 2.302576
# iteration 400 / 500: loss 2.302575
# training accuracy: 0.130653
# validation accuracy: 0.143000
# 49000
# 200
# iteration 0 / 500: loss 2.302643
# iteration 100 / 500: loss 2.302635
# iteration 200 / 500: loss 2.302640
# iteration 300 / 500: loss 2.302636
# iteration 400 / 500: loss 2.302629
# training accuracy: 0.131959
# validation accuracy: 0.137000
# 49000
# 200
# iteration 0 / 500: loss 2.303328
# iteration 100 / 500: loss 2.303332
# iteration 200 / 500: loss 2.303323
# iteration 300 / 500: loss 2.303353
# iteration 400 / 500: loss 2.303321
# training accuracy: 0.136673
# validation accuracy: 0.131000
# 49000
# 200
# iteration 0 / 500: loss 2.310294
# iteration 100 / 500: loss 2.310269
# iteration 200 / 500: loss 2.310239
# iteration 300 / 500: loss 2.310210
# iteration 400 / 500: loss 2.310157
# training accuracy: 0.131327
# validation accuracy: 0.128000
# 49000
# 200
# iteration 0 / 500: loss 2.379409
# iteration 100 / 500: loss 2.377396
# iteration 200 / 500: loss 2.375438
# iteration 300 / 500: loss 2.373583
# iteration 400 / 500: loss 2.371803
# training accuracy: 0.126327
# validation accuracy: 0.138000
# 49000
# 200
# iteration 0 / 500: loss 3.073311
# iteration 100 / 500: loss 2.894086
# iteration 200 / 500: loss 2.756618
# iteration 300 / 500: loss 2.653590
# iteration 400 / 500: loss 2.575605
# training accuracy: 0.135796
# validation accuracy: 0.141000
# 49000
# 200
# iteration 0 / 500: loss 9.990242
# iteration 100 / 500: loss 2.839003
# iteration 200 / 500: loss 2.340068
# iteration 300 / 500: loss 2.305401
# iteration 400 / 500: loss 2.302810
# training accuracy: 0.100449
# validation accuracy: 0.078000
# 49000
# 200
# iteration 0 / 500: loss 79.844050
# iteration 100 / 500: loss 2.302585
# iteration 200 / 500: loss 2.302585
# iteration 300 / 500: loss 2.302585
# iteration 400 / 500: loss 2.302585
# training accuracy: 0.100449
# validation accuracy: 0.078000
# 49000
# 200
# iteration 0 / 500: loss 771.995644
# iteration 100 / 500: loss 2.302585
# iteration 200 / 500: loss 2.302585
# iteration 300 / 500: loss 2.302585
# iteration 400 / 500: loss 2.302585
# training accuracy: 0.099755
# validation accuracy: 0.112000
# 49000
# 200
# iteration 0 / 500: loss 2.302581
# iteration 100 / 500: loss 2.160432
# iteration 200 / 500: loss 2.165367
# iteration 300 / 500: loss 2.114524
# iteration 400 / 500: loss 2.106851
# training accuracy: 0.270224
# validation accuracy: 0.280000
# 49000
# 200
# iteration 0 / 500: loss 2.302584
# iteration 100 / 500: loss 2.178916
# iteration 200 / 500: loss 2.096898
# iteration 300 / 500: loss 2.198260
# iteration 400 / 500: loss 2.082024
# training accuracy: 0.288327
# validation accuracy: 0.286000
# 49000
# 200
# iteration 0 / 500: loss 2.302639
# iteration 100 / 500: loss 2.156256
# iteration 200 / 500: loss 2.215917
# iteration 300 / 500: loss 2.194851
# iteration 400 / 500: loss 2.147683
# training accuracy: 0.292673
# validation accuracy: 0.295000
# 49000
# 200
# iteration 0 / 500: loss 2.303384
# iteration 100 / 500: loss 2.179764
# iteration 200 / 500: loss 2.209005
# iteration 300 / 500: loss 2.103969
# iteration 400 / 500: loss 2.003882
# training accuracy: 0.307898
# validation accuracy: 0.310000
# 49000
# 200
# iteration 0 / 500: loss 2.310278
# iteration 100 / 500: loss 2.214377
# iteration 200 / 500: loss 2.226815
# iteration 300 / 500: loss 2.234938
# iteration 400 / 500: loss 2.356268
# training accuracy: 0.241714
# validation accuracy: 0.238000
# 49000
# 200
# iteration 0 / 500: loss 2.379252
# iteration 100 / 500: loss 2.303548
# iteration 200 / 500: loss 2.343649
# iteration 300 / 500: loss 2.381522
# iteration 400 / 500: loss 2.375049
# training accuracy: 0.183061
# validation accuracy: 0.197000
# 49000
# 200
# iteration 0 / 500: loss 3.074746
# iteration 100 / 500: loss 2.302575
# iteration 200 / 500: loss 2.302577
# iteration 300 / 500: loss 2.302595
# iteration 400 / 500: loss 2.302560
# training accuracy: 0.100041
# validation accuracy: 0.098000
# 49000
# 200
# iteration 0 / 500: loss 9.967899
# D:\Personal Work\Kaggle\winter1516_assignment1\assignment1\cs231n\classifiers\neural_net.py:105: RuntimeWarning: divide by zero encountered in log
#   loss = np.mean(-np.log( np.exp(correct_scores) / np.sum(np.exp(scores), axis=1) )) + 0.5*reg*(np.sum(W1*W1) + np.sum(W2*W2))
# D:\Personal Work\Kaggle\winter1516_assignment1\assignment1\cs231n\classifiers\neural_net.py:105: RuntimeWarning: invalid value encountered in true_divide
#   loss = np.mean(-np.log( np.exp(correct_scores) / np.sum(np.exp(scores), axis=1) )) + 0.5*reg*(np.sum(W1*W1) + np.sum(W2*W2))
# D:\Personal Work\Kaggle\winter1516_assignment1\assignment1\cs231n\classifiers\neural_net.py:117: RuntimeWarning: invalid value encountered in true_divide
#   dF = np.exp(scores) / np.sum(np.exp(scores), keepdims=True, axis = 1)
# D:\Personal Work\Kaggle\winter1516_assignment1\assignment1\cs231n\classifiers\neural_net.py:131: RuntimeWarning: invalid value encountered in less
#   dB1[dB1 < 0] = 0
# D:\Personal Work\Kaggle\winter1516_assignment1\assignment1\cs231n\classifiers\neural_net.py:81: RuntimeWarning: invalid value encountered in less
#   res1[res1 < 0] = 0
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# D:\Personal Work\Kaggle\winter1516_assignment1\assignment1\cs231n\classifiers\neural_net.py:258: RuntimeWarning: invalid value encountered in less
#   res1[res1 < 0] = 0
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 79.666691
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 769.961737
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302586
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302601
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302672
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.303337
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.310353
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.379359
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 3.073437
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 10.022898
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 79.240176
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 775.611805
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302579
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302605
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302672
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.303360
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.310309
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.379093
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 3.072775
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 9.976256
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 79.541332
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 775.537602
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302601
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302597
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302688
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.303346
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.310287
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.379074
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 3.072940
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 9.977314
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 79.581487
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 774.959466
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302612
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302611
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302669
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.303350
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.310261
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.379234
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 3.077396
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 9.985543
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 78.959008
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 767.818617
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302588
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302587
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302671
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.303340
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.310319
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.379610
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 3.066968
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 9.969282
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 79.014002
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 775.200866
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302576
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302590
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.302652
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.303410
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.310246
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 2.379559
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 3.070089
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 9.966686
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 78.942991
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# 49000
# 200
# iteration 0 / 500: loss 769.410912
# iteration 100 / 500: loss nan
# iteration 200 / 500: loss nan
# iteration 300 / 500: loss nan
# iteration 400 / 500: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# lr 1.000000e-10 reg 1.000000e-03 train accuracy: 0.112163 val accuracy: 0.115000
# lr 1.000000e-10 reg 1.000000e-02 train accuracy: 0.111959 val accuracy: 0.124000
# lr 1.000000e-10 reg 1.000000e-01 train accuracy: 0.117837 val accuracy: 0.140000
# lr 1.000000e-10 reg 1.000000e+00 train accuracy: 0.076306 val accuracy: 0.087000
# lr 1.000000e-10 reg 1.000000e+01 train accuracy: 0.089714 val accuracy: 0.082000
# lr 1.000000e-10 reg 1.000000e+02 train accuracy: 0.095857 val accuracy: 0.083000
# lr 1.000000e-10 reg 1.000000e+03 train accuracy: 0.114653 val accuracy: 0.099000
# lr 1.000000e-10 reg 1.000000e+04 train accuracy: 0.096980 val accuracy: 0.105000
# lr 1.000000e-10 reg 1.000000e+05 train accuracy: 0.087184 val accuracy: 0.079000
# lr 1.000000e-10 reg 1.000000e+06 train accuracy: 0.103673 val accuracy: 0.113000
# lr 1.668101e-08 reg 1.000000e-03 train accuracy: 0.103367 val accuracy: 0.082000
# lr 1.668101e-08 reg 1.000000e-02 train accuracy: 0.099306 val accuracy: 0.115000
# lr 1.668101e-08 reg 1.000000e-01 train accuracy: 0.109490 val accuracy: 0.086000
# lr 1.668101e-08 reg 1.000000e+00 train accuracy: 0.092612 val accuracy: 0.088000
# lr 1.668101e-08 reg 1.000000e+01 train accuracy: 0.111816 val accuracy: 0.106000
# lr 1.668101e-08 reg 1.000000e+02 train accuracy: 0.086653 val accuracy: 0.093000
# lr 1.668101e-08 reg 1.000000e+03 train accuracy: 0.087857 val accuracy: 0.081000
# lr 1.668101e-08 reg 1.000000e+04 train accuracy: 0.104592 val accuracy: 0.105000
# lr 1.668101e-08 reg 1.000000e+05 train accuracy: 0.078837 val accuracy: 0.084000
# lr 1.668101e-08 reg 1.000000e+06 train accuracy: 0.093694 val accuracy: 0.106000
# lr 2.782559e-06 reg 1.000000e-03 train accuracy: 0.135816 val accuracy: 0.135000
# lr 2.782559e-06 reg 1.000000e-02 train accuracy: 0.130653 val accuracy: 0.143000
# lr 2.782559e-06 reg 1.000000e-01 train accuracy: 0.131959 val accuracy: 0.137000
# lr 2.782559e-06 reg 1.000000e+00 train accuracy: 0.136673 val accuracy: 0.131000
# lr 2.782559e-06 reg 1.000000e+01 train accuracy: 0.131327 val accuracy: 0.128000
# lr 2.782559e-06 reg 1.000000e+02 train accuracy: 0.126327 val accuracy: 0.138000
# lr 2.782559e-06 reg 1.000000e+03 train accuracy: 0.135796 val accuracy: 0.141000
# lr 2.782559e-06 reg 1.000000e+04 train accuracy: 0.100449 val accuracy: 0.078000
# lr 2.782559e-06 reg 1.000000e+05 train accuracy: 0.100449 val accuracy: 0.078000
# lr 2.782559e-06 reg 1.000000e+06 train accuracy: 0.099755 val accuracy: 0.112000
# lr 4.641589e-04 reg 1.000000e-03 train accuracy: 0.270224 val accuracy: 0.280000
# lr 4.641589e-04 reg 1.000000e-02 train accuracy: 0.288327 val accuracy: 0.286000
# lr 4.641589e-04 reg 1.000000e-01 train accuracy: 0.292673 val accuracy: 0.295000
# lr 4.641589e-04 reg 1.000000e+00 train accuracy: 0.307898 val accuracy: 0.310000
# lr 4.641589e-04 reg 1.000000e+01 train accuracy: 0.241714 val accuracy: 0.238000
# lr 4.641589e-04 reg 1.000000e+02 train accuracy: 0.183061 val accuracy: 0.197000
# lr 4.641589e-04 reg 1.000000e+03 train accuracy: 0.100041 val accuracy: 0.098000
# lr 4.641589e-04 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.641589e-04 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.641589e-04 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e-02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.742637e-02 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e-02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.291550e+01 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e-02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.154435e+03 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e-02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.593814e+05 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e-02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.994843e+07 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e-03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e-02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e-01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+00 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+01 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+02 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+10 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.310000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print( 'Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.327
